# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import random
from zipfile import ZipFile
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
with ZipFile('pc6.zip') as zip_file:
    names = zip_file.namelist()
    with zip_file.open(names[0]) as data_file:
        df = pd.read_csv(data_file, index_col=0)

# %% [markdown]
# |Label|Meaning|
# |:-------|:---------|
# |PC6| the 6 character postal code of the area|
# | INWONER| the number of inhabitants rounded to the level of 5|
# | MAN| the number of male inhabitants rounded to the level of 5|
# | VROUW| the number of female inhabitants rounded to the level of 5|
# | INW_014| the number of inhabitants aged 0 to 15 rounded to the level of 5|
# | INW_1524| the number of inhabitants aged 15 to 25 rounded to the level of 5|
# | INW_2544| the number of inhabitants aged 25 to 45 rounded to the level of 5|
# | INW_4564| the number of inhabitants aged 45 to 65 rounded to the level of 5|
# | INW_65PL| the number of inhabitants aged 65+ rounded to the level of 5|
# | P_NL_ACHTG| the percentage of people for which both parent are born in the Netherlands |
# | P_WE_MIG_A| the percentage of people for which at least one of the parents is born outside of NL but in Europe (excluding TR), North-America, Oceania, JP or IN|
# | P_NW_MIG_A| the percentage of people for which at least one of the parents is born outside of Europe (excluding TR), North-America, Oceania, JP or IN|
# | AANTAL_HH| the number of households rounded to 5
# | TOTHH_EENP| the number of single person households rounded to 5|
# | TOTHH_MPZK| the number of multiple person households without childeren rounded to 5|
# | GEM_HH_GR| the average size of a household|
# | WONING| the number of dwellings in the area|
# | WONVOOR45| the number of dwellings build before 1945 in the area|
# | P_HUURWON| the percentage of rental dwelllings in the area|
# | WOZWONING| the average WOZ value of the dwellings in the area|
# | UITKMINAOW| The number of people living on AOW|

# %%
pd.DataFrame(df.describe(include='all').transpose())

# %%
variables = df.columns.drop('PC6')
data = df[variables]
correlation_matrix = data.corr()
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, mask=mask)
plt.title('Correlation Matrix')
plt.show()

# %%
df['P_VROUW'] = df['VROUW']/df['INWONER']
df = df.drop(columns=['MAN', 'VROUW'])

# %%
df.isna().sum()

# %%
zero_fills = (df['P_NL_ACHTG'] + df['P_WE_MIG_A'].fillna(0) + df['P_NW_MIG_A'].fillna(0)) >89
df.loc[zero_fills, 'P_NL_ACHTG'] =  df.loc[zero_fills, 'P_NL_ACHTG'].fillna(0) 
df.loc[zero_fills, 'P_WE_MIG_A'] =  df.loc[zero_fills, 'P_WE_MIG_A'].fillna(0) 
df.loc[zero_fills, 'P_NW_MIG_A'] =  df.loc[zero_fills, 'P_NW_MIG_A'].fillna(0)

# %%
for col in df.columns[df.isna().sum() > 0]:
    df[col+'_na'] = df[col].isna().astype(int)
    df[col] = df[col].fillna(0)

# %%
df['INWONER'] = df['INWONER'].fillna(5)
df['AANTAL_HH'] = df['AANTAL_HH'].fillna(5)

# %%
y = df['WOZWONING'] > df['WOZWONING'].mean()
x = df.drop(columns=['WOZWONING','PC6']).fillna(-1)

# %%
mms = MinMaxScaler()
x = mms.fit_transform(x)

# %% [markdown]
# Setting the random seeds

# %%
np.random.seed(1)
random.seed(1)

# %%
x.shape

# %%
x_train, x_test, y_train, y_test = train_test_split(torch.tensor(x, dtype=torch.float32), 
                                                    torch.tensor(y.values, dtype=torch.float32).reshape(-1, 1), 
                                                    train_size=0.7, 
                                                    shuffle=True,
                                                    random_state=0)
loader = torch.utils.data.DataLoader(list(zip(x_train, y_train)),
                                     batch_size=100,
                                     num_workers=4,)

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.l1 = nn.Linear(33, 33)
        self.l2 = nn.Linear(33, 1)

    def forward(self, x):
        x = self.l1(x)
        x = nn.functional.relu(x)
        x = self.l2(x)
        x = nn.functional.sigmoid(x)
        return x

# %%
def train_model(iter, model, x_train, y_train, x_test, y_test, lr):
    criterion = torch.nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.99)
    train_acc = []
    test_acc = []

    for epoch in range(iter):
        y1 = model(x_train)
        loss = criterion(y1, y_train)
        train_acc.append(((y1>0.5) == (y_train>0.5)).sum()/len(y_train))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        with torch.no_grad():
            test_acc.append(((model(x_test)>0.5) == (y_test>0.5)).sum()/len(y_test))


    return train_acc, test_acc

# %%
model = MyModel()

# %%
train_acc, test_acc = train_model(500, model, x_train, y_train, x_test, y_test, 0.01)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.gca()
ax.plot(train_acc, label='train')
ax.plot(test_acc, label='test')
ax.legend()

# %%
f'The test accuracy is {test_acc[-1].item():.3}'
